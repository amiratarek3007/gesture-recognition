# %%
import time
import cv2
import numpy as np
import math
import os
import time
import scipy.misc
import sys

# %%
cv2.ocl.setUseOpenCL(False)
if str(cv2.__version__)[0] != "3":
    raise "please install opencv version 3.?"

try:
    import winsound
except ImportError:
    def playsound(frequency,duration):
        os.system('play --no-show-progress --null --channels 1 synth %s sine %f' % (duration, frequency))
import sys



#capture_duration = 4

save_path = None
# parameters
cap_region_x_begin=0.5  # start point/total width
cap_region_y_end=0.8  # start point/total width
threshold = 40  #  BINARY threshold
blurValue = 41  # GaussianBlur parameter
bgSubThreshold = 50
isBgCaptured = 0   # bool, whether the background captured

# Camera


path = "videoooooooooos"
print("save :", save_path)
#playsound(440, 1)
#print("start writing images to class:", k_arg)
if not os.path.exists(path):
    os.makedirs(path)


s = -100
v = 10


def new_video(path,video_number,duration):
    t1 = time.time()
    camera = cv2.VideoCapture(0)
    start_time = time.time()
    fourcc = cv2.VideoWriter_fourcc(*'MP4V')
    out = cv2.VideoWriter(str(video_number)+".mp4", fourcc, 20, (640, 480))
    while( int(time.time() - start_time) < duration ):
        ret, frame = camera.read()
        frame = cv2.flip(frame, 1)
        #cv2.imwrite(path+str(video_number)+str(count)+".jpg",frame)
        #count=count+1
        print("///////////////////////////////////")
        # Display the resulting frame
        out.write(frame)
        cv2.imshow('frame', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    print(time.time()-t1)
    print("sttart to release")
    camera.release()
    out.release()
    print("releasing")
    cv2.destroyAllWindows()
    print("released")






while(True):
    s += 1
    if s == 0:
        v += 1
        
        winsound.Beep(1000, 1)
        new_video(path,v,3.2)
        s = -100
    if v == 21:
        break
# Out:
# save : None
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ///////////////////////////////////
# ...
